# %% [markdown]
# <a href="https://colab.research.google.com/github/esddras/INTED2025/blob/main/ALP_V25_ESDDRAS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Algoritimo e Logica de Programação

# %% [markdown]
# ##Variáveis

# %%
a = 5
b = 10
print(a+b)
# Out:
# 15

# %%
a = int(input('digite um número:'))
b = int(input('digite outro número:'))
print(a+b)
# Out:
# digite um número:21
# digite outro número:32
# 53

# %%
n1 = int(input('Digite um número:'))
n2 = int(input('Digite outro número:'))
expo = numero1 ** numero2
print(f'o numero {n1} elevado ao numero {n2} é igual a: {expo}')
# Out:
# Digite um número:2
# Digite outro número:2
# o numero 2 elevado ao numero 2 é igual a: 4

# %%
nome = input('digite um nome:')
idade = str(input('digite uma idade:'))
print(f'olá, meu nome é {nome} e eu tenho {idade} anos!')
# Out:
# digite um nome:esdras
# digite uma idade:16
# olá, meu nome é esdras e eu tenho 16 anos!

# %%
#calculadora de IMC
peso = float(input('digite seu peso:'))
altura = float(input('digite sua altura:'))
imc = peso / (altura * altura)
print(f'seu imc é:{imc:.2f}')
# Out:
# digite seu peso:85
# digite sua altura:1.87
# seu imc é:24.31
